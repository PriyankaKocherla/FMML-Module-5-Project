# %% [markdown]
# <a href="https://colab.research.google.com/github/PriyankaKocherla/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-05 05:09:55--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  56.6MB/s    in 1.2s
#
# 2024-04-05 05:10:00 (56.6 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36142   1207.1365v1  It is well known that there may be many causal...  stat
# 23512   1304.0823v2  We present an image representation method whic...    cs
# 26096  1608.06557v1  In Neural Networks (NN), Adaptive Activation F...    cs
# 14492  cs/0105019v1  This thesis presents a broad-coverage probabil...    cs
# 38115   1210.5898v1  We report applications of language technology ...    cs
# ...             ...                                                ...   ...
# 7600   1802.04617v1  While optimizing convex objective (loss) funct...  stat
# 2878   1803.07712v2  In this paper, we deal with the problem of inf...  stat
# 5385    1306.3917v1  Sampling from distributions to find the one wi...  stat
# 40227  1802.02423v1  In contrast to conventional, univariate analys...  stat
# 4017    1102.2748v1  Inspired by biological vision systems, the ove...    cs
#
#                                                    title  year  \
# 36142  Towards Characterizing Markov Equivalence Clas...  2012
# 23512  Lie Algebrized Gaussians for Image Representation  2013
# 26096  Neural Networks with Smooth Adaptive Activatio...  2016
# 14492  Robust Probabilistic Predictive Syntactic Proc...  2001
# 38115  Some Chances and Challenges in Applying Langua...  2012
# ...                                                  ...   ...
# 7600   Fast Global Convergence via Landscape of Empir...  2018
# 2878   Causal Inference on Discrete Data via Estimati...  2018
# 5385              On Finding the Largest Mean Among Many  2013
# 40227  On the Generalizability of Linear and Non-Line...  2018
# 4017   Feature Selection via Sparse Approximation for...  2011
#
#                                                 keywords
# 36142  [explanations, consistent, represent, explanat...
# 23512  [representation, analyzing, probability, unive...
# 26096  [activation, functions, parameters, activation...
# 14492  [probabilistic, application, recognition, conn...
# 38115  [applications, technology, analyzing, historic...
# ...                                                  ...
# 7600   [optimizing, objective, functions, powerhouse,...
# 2878   [inferring, directions, considering, distribut...
# 5385   [distributions, applications, mathematically, ...
# 40227  [conventional, univariate, multivariate, funct...
# 4017   [biological, cardinality, increasingly, recogn...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36142    [explanations, consistent, represent, explanat...
# 23512    [representation, analyzing, probability, unive...
# 26096    [activation, functions, parameters, activation...
# 14492    [probabilistic, application, recognition, conn...
# 38115    [applications, technology, analyzing, historic...
#                                ...
# 10961    [prediction, important, normalized, symmetric,...
# 25596    [possibilistic, clustering, algorithms, presen...
# 6482     [discovering, relations, fundamental, reasonin...
# 28741    [development, convolutional, efficient, segmen...
# 959      [chemicals, additives, medicines, compounds, b...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8744 words.
# Out of those 4556 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a40f69e3-8871-4152-80f6-c1bb46585373" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a40f69e3-8871-4152-80f6-c1bb46585373")) {                    Plotly.newPlot(                        "a40f69e3-8871-4152-80f6-c1bb46585373",                        [{"x":["orientation","independence","relations","ancestral","construct","representation","conditional","explanation","selection","representative","characterizing","explanations","represent","essential","relationships","variables","consistent","equivalence","benchmark","performance","analyzing","gaussians","components","procedure","recognition","characteristic","constructed","probability","background","component","universal","corresponding","combining","differentiable","activation","significantly","lipschitz","empirically","arbitrary","functions","complexity","particular","polynomial","regression","approximate","shattering","magnitude","overfitting","piecewise","regularizing","continuous","dimension","evaluated","parameters","classification","feedforward","syntactic","reduction","incrementally","processing","presented","probabilistic","psycholinguistic","perplexity","newspaper","perspective","improvements","motivated","connected","conversations","telephone","demonstrated","spontaneous","empirical","dependencies","application","predictive","structures","derivations","modifications","additional","interpolation","pragmatic","information","sophisticated","collection","government","literature","strengthen","documents","historical","challenges","applications","technology","techniques","experience","collaboration","supporting","scientists","technologies","historians","institute","conceptualization","complement","therefore","throughout","practical","different","potentially","balancing","approximating","visualize","optimization","expansion","consistently","understanding","important","relatively","consolidate","efficiency","popularity","maintaining","indispensable","operations","management","shortages","visualizing","approaches","sequentially","improvement","identifying","infeasible","libraries","performed","acceleration","measurements","heuristic","simulations","screening","interesting","implementation","thousands","successful","accelerated","molecules","outperforms","exploration","collecting","additionally","throughput","experiments","discovery","baselines","similarly","currently","distributed","encodings","programming","solutions","argumentation","efficient","prominent","semantics","benchmarks","disjunctions","outperform","challenging","harvesting","annotated","community","difficult","precision","detection","qualitative","performing","autonomous","surrounding","quantitative","supervised","detecting","investigate","sequential","environment","rewarding","demonstrate","algorithms","hippocampal","interactions","hippocampus","reinforcement","counterfactual","randomization","discrimination","including","achieving","statistical","mechanism","instances","knowledge","intensive"],"y":[26,31,89,2,89,384,86,16,172,34,16,12,108,67,71,116,65,20,197,893,55,12,102,124,366,30,61,148,81,90,40,138,97,21,39,260,11,63,83,217,226,261,68,110,122,1,60,33,13,10,98,56,142,246,482,25,54,87,19,292,163,174,4,9,5,62,121,58,64,14,3,93,9,145,45,230,44,120,5,15,115,17,4,715,28,60,2,116,7,74,20,132,463,52,359,42,13,21,10,37,3,3,3,21,128,13,140,744,38,20,17,13,326,21,39,159,330,60,2,169,20,20,9,71,59,1,16,442,19,138,65,9,5,138,12,49,58,46,12,80,128,21,64,12,0,259,60,9,59,14,618,51,69,22,60,108,8,117,167,15,415,18,115,104,2,86,269,3,79,79,155,89,357,50,89,59,14,73,195,71,145,64,121,4,546,616,0,62,2,105,5,3,16,242,76,178,104,83,367,26],"type":"bar"},{"x":["orientation","independence","relations","ancestral","construct" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4556,), (4556, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8275

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4035087719298245);'>Improving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficiency</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058824);'>Inductive</span> <span style=''>Logic</span> <span style='background-color:rgba(0, 255, 0, 0.36046511627906974);'>Programming</span> <span style=''>Through</span> <span style=''>the</span> <span style=''>Use</span> <span style=''>of</span> <span style=''>Query</span> <span style=''>Packs</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.5294117647058824);'>Inductive</span> <span style=''>logic</span> <span style='background-color:rgba(0, 255, 0, 0.36046511627906974);'>programming</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.30909090909090914);'>relational</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>paradigm</span> <span style=''>for</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>or</span> <span style=''>data</span> <span style=''>mining</span> <span style=''>However</span> <span style=''>in</span> <span style=''>order</span> <span style=''>for</span> <span style=''>ILP</span> <span style=''>to</span> <span style=''>become</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practically</span> <span style=''>useful</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>of</span> <span style=''>ILP</span> <span style=''>systems</span> <span style=''>must</span> <span style=''>improve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>substantially</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>a</span> <span style=''>query</span> <span style=''>pack</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structures</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>similar</span> <span style=''>queries</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Furthermore</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>mechanism</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>executing</span> <span style=''>such</span> <span style=''>query</span> <span style=''>packs</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>analysis</span> <span style=''>shows</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considerable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style='background-color:rgba(0, 255, 0, 0.4578313253012048);'>improvements</span> <span style=''>can</span> <span style=''>be</span> <span style=''>achieved</span> <span style=''>through</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>this</span> <span style=''>query</span> <span style=''>pack</span> <span style='background-color:rgba(0, 255, 0, 0.8125);'>execution</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>mechanism</span> <span style=''>This</span> <span style=''>claim</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supported</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>results</span> <span style=''>obtained</span> <span style=''>by</span> <span style='background-colo ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style=''>Real</span> <span style=''>Time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Sentiment</span> <span style=''>Analysis</span> <span style=''>for</span> <span style=''>Big</span> <span style=''>Data</span> <span style=''>Social</span> <span style=''>Streams</span> <br/><br/><span style=''>Big</span> <span style=''>data</span> <span style=''>trend</span> <span style=''>has</span> <span style=''>enforced</span> <span style=''>the</span> <span style=''>data</span> <span style=''>centric</span> <span style=''>systems</span> <span style=''>to</span> <span style=''>have</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>fast</span> <span style=''>data</span> <span style=''>streams</span> <span style=''>In</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytics</span> <span style=''>on</span> <span style=''>stream</span> <span style=''>data</span> <span style=''>has</span> <span style=''>formed</span> <span style=''>into</span> <span style=''>a</span> <span style=''>new</span> <span style=''>research</span> <span style=''>field</span> <span style=''>which</span> <span style=''>aims</span> <span style=''>to</span> <span style=''>answer</span> <span style=''>queries</span> <span style=''>about</span> <span style=''>what</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>happening</span> <span style=''>now</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>negligible</span> <span style=''>delay</span> <span style=''>The</span> <span style=''>real</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>with</span> <span style=''>real</span> <span style=''>time</span> <span style=''>stream</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>is</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>impossible</span> <span style=''>to</span> <span style=''>store</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>instances</span> <span style=''>of</span> <span style=''>data</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>therefore</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analytical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>are</span> <span style=''>utilized</span> <span style=''>To</span> <span style=''>perform</span> <span style=''>real</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analytics</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>of</span> <span style=''>data</span> <span style=''>should</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>in</span> <span style=''>a</span> <span style=''>way</span> <span style=''>that</span> <span style=''>only</span> <span style=''>a</span> <span style=''>short</span> <span style=''>summary</span> <span style=''>of</span> <span style=''>stream</span> <span style=''>is</span> <span style=''>stored</span> <span style=''>in</span> <span style=''>main</span> <span style=''>memory</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>due</span> <span style=''>to</span> <span style=''>high</span> <span style=''>speed</span> <span style=''>of</span> <span style=''>arrival</span> <span style=''>average</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>time</span> <span style=''>for</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>via</span> <span style=''>Gradient</span> <span style=''>Descent</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>Robust</span> <span style=''>PCA</span> <span style=''>in</span> <span style=''>the</span> <span style=''>fully</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>observed</span> <span style=''>settings</span> <span style=''>Without</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corruptions</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style=''>well</span> <span style=''>known</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333334);'>completion</span> <span style=''>problem</span> <span style=''>From</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.4999999999999999);'>standpoint</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>has</span> <span style=''>been</span> <span style=''>recently</span> <span style=''>well</span> <span style=''>studied</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>on</span> <span style=''>when</span> <span style=''>recovery</span> <span style=''>is</span> <span style=''>possible</span> <span style=''>(how</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.4339622641509434);'>observations</span> <span style=''>do</span> <span style=''>we</span> <span style=''>need</span> <span style=''>how</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corruptions</span> <span style=''>can</span> <span style=''>we</span> <span style=''>tolerate)</span> <span style=''>via</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>is</span> <span style=''>by</span> <span style=''>now</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understood</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>and</span> <span style=''>analyzes</span> <span style=''>a</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>greatly</span> <span style=''>reduces</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>above</span> <span style=''>problems</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(0, 255, 0, 0.30879345603271985);'>available</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>in</span> <span style=''>the</span> <span style=''>fully</span> <span style=''>observed</span> <span style=''>case</span> <span style=''>with</span> <span style=''>r</span> <span style=''>denoting</span> <span style=''>rank</span> <span style=''>and</span> <span style=''>d</span> <span style='background-color:rgba(255, 0, 0, 0.3846153846153847);'>dimension</span> <span style=''>we</span> <span style=''>reduce</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correspondence</span> <span style=''>Between</span> <span style=''>Random</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style=''>Field</span> <span style=''>Theory</span> <br/><br/><span style=''>A</span> <span style=''>number</span> <span style=''>of</span> <span style=''>recent</span> <span style=''>papers</span> <span style=''>have</span> <span style=''>provided</span> <span style=''>evidence</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>design</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>about</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>may</span> <span style=''>be</span> <span style=''>tackled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretically</span> <span style=''>by</span> <span style=''>studying</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>random</span> <span style=''>networks</span> <span style=''>However</span> <span style=''>until</span> <span style=''>now</span> <span style=''>the</span> <span style=''>tools</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>random</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>have</span> <span style=''>been</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relatively</span> <span style=''>ad</span> <span style=''>hoc</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>pre</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activations</span> <span style=''>in</span> <span style=''>random</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>can</span> <span style=''>be</span> <span style=''>exactly</span> <span style=''>mapped</span> <span style=''>onto</span> <span style=''>lattice</span> <span style=''>models</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>physics</span> <span style=''>We</span> <span style=''>argue</span> <span style=''>that</span> <span style=''>several</span> <span style=''>previous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>networks</span> <span style=''>actually</span> <span style=''>studied</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>factorial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>the</span> <span style=''>full</span> <span style=''>lattice</span> <span style=''>model</span> <span style=''>For</span> <span style=''>random</span> <span style=''>linear</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>rectified</span> <span style=''>linear</span> <span style=''>networks</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>lattice</span> <span style=''>models</span> <span style=''>in</span> <span style=''>the</span> < ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.0704830053667263)
# 	knowledge (0.13130590339892664)
# 	segmentation (0.07227191413237925)
# 	architecture (0.09230769230769231)
# 	representation (0.13738819320214668)
# 	information (0.2558139534883721)
# 	detection (0.12772808586762074)
# 	different (0.2661896243291592)
# 	convolutional (0.13059033989266547)
# 	recognition (0.13094812164579606)
#
# Some Statistics words are:
# 	stochastic (0.1401496259351621)
# 	statistical (0.1541147132169576)
# 	estimation (0.16758104738154614)
# 	variables (0.143142144638404)
# 	algorithm (0.4029925187032419)
# 	distribution (0.17755610972568578)
# 	theoretical (0.16608478802992518)
# 	inference (0.19551122194513715)
# 	dimensional (0.18902743142144637)
# 	regression (0.17206982543640897)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a8fa2462-119c-4518-98e7-dd3b54062d40" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8fa2462-119c-4518-98e7-dd3b54062d40")) {                    Plotly.newPlot(                        "a8fa2462-119c-4518-98e7-dd3b54062d40",                        [{"x":["orientation","independence","relations","ancestral","construct","representation","conditional","explanation","selection","representative","characterizing","explanations","represent","essential","relationships","variables","consistent","equivalence","benchmark","performance","analyzing","gaussians","components","procedure","recognition","characteristic","constructed","probability","background","component","universal","corresponding","combining","differentiable","activation","significantly","lipschitz","empirically","arbitrary","functions","complexity","particular","polynomial","regression","approximate","shattering","magnitude","overfitting","piecewise","regularizing","continuous","dimension","evaluated","parameters","classification","feedforward","syntactic","reduction","incrementally","processing","presented","probabilistic","psycholinguistic","perplexity","newspaper","perspective","improvements","motivated","connected","conversations","telephone","demonstrated","spontaneous","empirical","dependencies","application","predictive","structures","derivations","modifications","additional","interpolation","pragmatic","information","sophisticated","collection","government","literature","strengthen","documents","historical","challenges","applications","technology","techniques","experience","collaboration","supporting","scientists","technologies","historians","institute","conceptualization","complement","therefore","throughout","practical","different","potentially","balancing","approximating","visualize","optimization","expansion","consistently","understanding","important","relatively","consolidate","efficiency","popularity","maintaining","indispensable","operations","management","shortages","visualizing","approaches","sequentially","improvement","identifying","infeasible","libraries","performed","acceleration","measurements","heuristic","simulations","screening","interesting","implementation","thousands","successful","accelerated","molecules","outperforms","exploration","collecting","additionally","throughput","experiments","discovery","baselines","similarly","currently","distributed","encodings","programming","solutions","argumentation","efficient","prominent","semantics","benchmarks","disjunctions","outperform","challenging","harvesting","annotated","community","difficult","precision","detection","qualitative","performing","autonomous","surrounding","quantitative","supervised","detecting","investigate","sequential","environment","rewarding","demonstrate","algorithms","hippocampal","interactions","hippocampus","reinforcement","counterfactual","randomization","discrimination","including","achieving","statistical","mechanism","instances","knowledge","intensive","classifier","classifiers","structure","extensive","convolutional","discriminative","attention","dimensional","optimizing","consuming","sufficient","remembering","interpreted","vanishing","conceptually","subsequently","compositional","recurrent","protection","forgetting","gradients","intuitively","discarded","recursive","influencing","representations","significant","competitive","transform","topographic","algorithm","unfortunately","trajectories","associates","considers","attraction","segmenting","overestimate","following","iterative","adaptative","neighborhood","constructs","correctly","partition","overlapping","eliminate","watershed","localization","trajectory","estimating","synthesis","qualitatively","adversarial", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	molecules
# 	hippocampal
# 	nomination
# 	epidemics
# 	signaling
# 	dependences
# 	fmathcalx
# 	discretizations
# 	unnecessarily
# 	nonstandard
# 	proportionality
# 	percolation
# 	bivariate
# 	embarrassingly
# 	detectability
# 	smoothers
# 	irregularly
# 	consonants
# 	subgaussian
# 	stationarity
# Some words which never appear in Statistics papers:
# 	syntactic
# 	psycholinguistic
# 	newspaper
# 	telephone
# 	spontaneous
# 	historians
# 	institute
# 	conceptualization
# 	consolidate
# 	argumentation
# 	disjunctions
# 	adaptative
# 	watershed
# 	impressions
# 	stylistic
# 	photographers
# 	nonmonotonic
# 	propositional
# 	synergies
# 	coalition

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.07635513443672e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666
